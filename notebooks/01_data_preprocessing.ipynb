# %%
import pandas as pd
print("Hi Tanmeet! Your notebook is working 🎉")

# %%
import pandas as pd
import openpyxl

df = pd.read_excel('../data/raw/Data_final.xlsx')
df.head()

# %%
df.info()

# %%
df.isnull().sum()

# %%
df.describe()

# %%
# Save cleaned version
df.to_csv('../data/cleaned/cleaned_data.csv', index=False)
